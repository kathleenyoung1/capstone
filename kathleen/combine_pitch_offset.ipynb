# %%
import pandas as pd

# %%
onset = pd.read_csv("data.csv")
pitch = pd.read_csv("pitch.csv")
gs = pd.read_csv("BERT4GS_SCOTUS_GOLD.csv")

# %%
pitch['file_name'] = pitch['file'] + '.wav'
gs['file_name'] = gs['Case'] + '.wav'
pitch['mp3_name'] = pitch['file'] + '_' + pitch['Unnamed: 0'].apply(str) + '.mp3'
#pitch['transcript_2'] = pitch['transcipt'].str.replace(' ', '')
#onset['text_2'] = onset['text'].str.replace(' ', '')

# %%
onset.head()
# Out:
#     start     end            speaker    speaker_role  \
# 0  126.76  169.12  John_G_Roberts_Jr  scotus_justice
# 1  227.24  242.92  John_G_Roberts_Jr  scotus_justice
# 2  297.56  341.56    Clarence_Thomas  scotus_justice
# 3  431.92  465.40    Clarence_Thomas  scotus_justice
# 4  510.88  588.40   Stephen_G_Breyer  scotus_justice
#
#                                                 text          file  line  \
# 0  Mr. Garre, how should we analyze the case if w...  142-orig.wav     2
# 1  Well, the -- the Special Master concluded that...  142-orig.wav     4
# 2  Thank you, Mr. Chief Justice. Mr. Garre, a cou...  142-orig.wav     7
# 3  Well, that's -- you know, that's interesting b...  142-orig.wav     9
# 4  Well, the part I don't understand, I mean, you...  142-orig.wav    12
#
#    length  start_idx  end_idx  word_count  onset_count  onset_rate  \
# 0   42.36    2028160  2705920         105          136    3.210576
# 1   15.68    3635840  3886720          49           62    3.954082
# 2   44.00    4760960  5464960         128          133    3.022727
# 3   33.48    6910720  7446400          83          123    3.673835
# 4   77.52    8174080  9414400         191          201    2.592879
#
#    onset_time_diff_mean  onset_time_diff_var  onset_strength_mean  \
# 0              0.311704             0.069920             0.981030
# 1              0.247607             0.046463             0.882956
# 2              0.326061             0.080029             0.899064
# 3              0.268328             0.043334             0.769803
# 4              0.374720             0.144677             0.713865
#
#    onset_strength_seg_var  onset_strength_seg_std  onset_delta_abs_mean  \
# 0                2.763874                1.662490              0.167881
# 1                2.563534                1.601104              0.161835
# 2                3.517396                1.875472              0.182482
# 3                1.723238                1.312722              0.131871
# 4                2.010508                1.417924              0.134689
#
#    onset_delta_var
# 0         0.074542
# 1         0.072180
# 2         0.091160
# 3         0.042263
# 4         0.055303

# %%
pitch.head()
# Out:
#    Unnamed: 0                                          transcipt  \
# 0           0  Mr. Silbert, I want to pick up on that very la...
# 1           1  Yes, thank you, Mr. Chief Justice. Counsel, I ...
# 2           2  I'd like to -- to pick up on that last questio...
# 3           3  Section 1606 on which you rely makes a foreign...
# 4           4  One other question. If we were to rule, hypoth...
#
#             speakers     file  batch    start      end  start_rounded  \
# 0  John_G_Roberts_Jr  18-1447      0  135.905  161.165            136
# 1    Clarence_Thomas  18-1447      1  226.020  244.535            226
# 2   Stephen_G_Breyer  18-1447      2  381.320  421.655            381
# 3  Samuel_A_Alito_Jr  18-1447      3  529.875  561.440            530
# 4  Samuel_A_Alito_Jr  18-1447      4  626.835  646.140            627
#
#    end_rounded  log_mean_pitch  log_stdev_pitch  rate_of_change_log_variance  \
# 0          161        5.414151         0.313577                     0.001543
# 1          245        4.585400         0.031675                     0.000586
# 2          422        5.014000         0.273777                     0.000811
# 3          561        4.958729         0.144191                     0.001199
# 4          646        5.800112         0.842117                     0.000702
#
#    onsets  onset_mean  word_count  duration    file_name       mp3_name
# 0      90    0.917828          57    25.260  18-1447.wav  18-1447_0.mp3
# 1      39    0.742995          45    18.515  18-1447.wav  18-1447_1.mp3
# 2     133    0.762228         102    40.335  18-1447.wav  18-1447_2.mp3
# 3      78    0.765330          61    31.565  18-1447.wav  18-1447_3.mp3
# 4      44    0.728004          40    19.305  18-1447.wav  18-1447_4.mp3

# %%
gs.head()
# Out:
#    Unnamed: 0     Case                Spkr    Start      End  \
# 0           0  18-1447  John_G_Roberts_Jr_  135.905  161.165
# 1           1  18-1447    Clarence_Thomas_  226.020  244.535
# 2           2  18-1447   Stephen_G_Breyer_  381.320  421.655
# 3           3  18-1447  Samuel_A_Alito_Jr_  529.875  561.440
# 4           4  18-1447  Samuel_A_Alito_Jr_  626.835  646.140
#
#                                               Speech  BERT-GS_Scores  \
# 0   Mr. Silbert, I want to pick up on that very l...       -1.148735
# 1   Yes, thank you, Mr. Chief Justice. Counsel, I...       -1.203924
# 2   I'd like to to pick up on that last question....       -0.638383
# 3   Section 1606 on which you rely makes a foreig...       -0.519051
# 4   One other question. If we were to rule, hypot...       -1.262270
#
#      file_name
# 0  18-1447.wav
# 1  18-1447.wav
# 2  18-1447.wav
# 3  18-1447.wav
# 4  18-1447.wav

# %%
len(onset)
# Out:
# 2545

# %%
len(pitch)
# Out:
# 2537

# %%
len(gs)
# Out:
# 2557

# %%
len(onset.merge(pitch, left_on=['file', 'start', 'end'], right_on = ['file_name', 'start', 'end']))
# Out:
# 1121

# %%
#onset[onset['file'] == '18-1447.wav']

# %%
#pitch

# %%
#out = onset.merge(pitch, left_index=True, right_index = True)
#out.to_csv('out.csv')

# %%
len(onset.merge(pitch, left_on=['file', 'text'], right_on = ['file_name', 'transcipt']))
# looks like its this one then
# Out:
# 2207

# %%
#pitch['transcipt']

# %%
#len(onset.merge(pitch, left_on=['file', 'text_2'], right_on = ['file_name', 'transcript_2']))

# %%
out = onset.merge(pitch, left_on=['file', 'text'], right_on = ['file_name', 'transcipt'])
out.head()
# Out:
#    start_x   end_x            speaker    speaker_role  \
# 0   126.76  169.12  John_G_Roberts_Jr  scotus_justice
# 1   227.24  242.92  John_G_Roberts_Jr  scotus_justice
# 2   297.56  341.56    Clarence_Thomas  scotus_justice
# 3   431.92  465.40    Clarence_Thomas  scotus_justice
# 4   510.88  588.40   Stephen_G_Breyer  scotus_justice
#
#                                                 text        file_x  line  \
# 0  Mr. Garre, how should we analyze the case if w...  142-orig.wav     2
# 1  Well, the -- the Special Master concluded that...  142-orig.wav     4
# 2  Thank you, Mr. Chief Justice. Mr. Garre, a cou...  142-orig.wav     7
# 3  Well, that's -- you know, that's interesting b...  142-orig.wav     9
# 4  Well, the part I don't understand, I mean, you...  142-orig.wav    12
#
#    length  start_idx  end_idx  ...  end_rounded  log_mean_pitch  \
# 0   42.36    2028160  2705920  ...          169        5.372137
# 1   15.68    3635840  3886720  ...          243        5.390368
# 2   44.00    4760960  5464960  ...          342        6.363312
# 3   33.48    6910720  7446400  ...          465        5.337352
# 4   77.52    8174080  9414400  ...          588        5.409414
#
#    log_stdev_pitch  rate_of_change_log_variance  onsets  onset_mean  \
# 0         0.258085                     0.001515     136    0.981030
# 1         0.391115                     0.002066      62    0.882956
# 2         0.706816                     0.001416     133    0.899064
# 3         0.697671                     0.000911     123    0.769803
# 4         0.353881                     0.002614     201    0.713865
#
#    word_count_y  duration     file_name           mp3_name
# 0           105     42.36  142-orig.wav  142-orig_2267.mp3
# 1            49     15.68  142-orig.wav  142-orig_2268.mp3
# 2           128     44.00  142-orig.wav  142-orig_2269.mp3
# 3            83     33.48  142-orig.wav  142-orig_2270.mp3
# 4           191     77.52  142-orig.wav  142-orig_2271.mp3
#
# [5 rows x 38 columns]

# %%
len(out.merge(gs, left_on = ['file_name', 'transcipt'], right_on = ['file_name', 'Speech']))
# Out:
# 0

# %%
len(out.merge(gs, left_on = ['file_name', 'start_y', 'end_y'], right_on = ['file_name', 'Start', 'End']))
# Out:
# 2100

# %%
out = out.merge(gs, left_on = ['file_name', 'start_y', 'end_y'], right_on = ['file_name', 'Start', 'End'])
# again looks like its this one

# %%
out.to_csv("out_for_inspection.csv")

# %%
out.columns
# Out:
# Index(['start_x', 'end_x', 'speaker', 'speaker_role', 'text', 'file_x', 'line',
#        'length', 'start_idx', 'end_idx', 'word_count_x', 'onset_count',
#        'onset_rate', 'onset_time_diff_mean', 'onset_time_diff_var',
#        'onset_strength_mean', 'onset_strength_seg_var',
#        'onset_strength_seg_std', 'onset_delta_abs_mean', 'onset_delta_var',
#        'Unnamed: 0_x', 'transcipt', 'speakers', 'file_y', 'batch', 'start_y',
#        'end_y', 'start_rounded', 'end_rounded', 'log_mean_pitch',
#        'log_stdev_pitch', 'rate_of_change_log_variance', 'onsets',
#        'onset_mean', 'word_count_y', 'duration', 'file_name', 'mp3_name',
#        'Unnamed: 0_y', 'Case', 'Spkr', 'Start', 'End', 'Speech',
#        'BERT-GS_Scores'],
#       dtype='object')

# %%
out = out[['file_name', 'mp3_name', 'speakers', 'word_count_y',  'start_y',
     'end_y', 'duration', 'transcipt', 'log_mean_pitch','log_stdev_pitch', 'rate_of_change_log_variance',
     'onset_count', 'onset_rate', 'onset_time_diff_mean', 'onset_time_diff_var', 'onset_strength_mean',
     'onset_strength_seg_var', 'onset_strength_seg_std', 'onset_delta_abs_mean', 'onset_delta_var', 'BERT-GS_Scores']]

# %%
out.head()
# Out:
#       file_name           mp3_name           speakers  word_count_y  start_y  \
# 0  142-orig.wav  142-orig_2267.mp3  John_G_Roberts_Jr           105   126.76
# 1  142-orig.wav  142-orig_2268.mp3  John_G_Roberts_Jr            49   227.24
# 2  142-orig.wav  142-orig_2269.mp3    Clarence_Thomas           128   297.56
# 3  142-orig.wav  142-orig_2270.mp3    Clarence_Thomas            83   431.92
# 4  142-orig.wav  142-orig_2271.mp3   Stephen_G_Breyer           191   510.88
#
#     end_y  duration                                          transcipt  \
# 0  169.12     42.36  Mr. Garre, how should we analyze the case if w...
# 1  242.92     15.68  Well, the -- the Special Master concluded that...
# 2  341.56     44.00  Thank you, Mr. Chief Justice. Mr. Garre, a cou...
# 3  465.40     33.48  Well, that's -- you know, that's interesting b...
# 4  588.40     77.52  Well, the part I don't understand, I mean, you...
#
#    log_mean_pitch  log_stdev_pitch  ...  onset_count  onset_rate  \
# 0        5.372137         0.258085  ...          136    3.210576
# 1        5.390368         0.391115  ...           62    3.954082
# 2        6.363312         0.706816  ...          133    3.022727
# 3        5.337352         0.697671  ...          123    3.673835
# 4        5.409414         0.353881  ...          201    2.592879
#
#    onset_time_diff_mean  onset_time_diff_var  onset_strength_mean  \
# 0              0.311704             0.069920             0.981030
# 1              0.247607             0.046463             0.882956
# 2              0.326061             0.080029             0.899064
# 3              0.268328             0.043334             0.769803
# 4              0.374720             0.144677             0.713865
#
#    onset_strength_seg_var  onset_strength_seg_std  onset_delta_abs_mean  \
# 0                2.763874                1.662490              0.167881
# 1                2.563534                1.601104              0.161835
# 2                3.517396                1.875472              0.182482
# 3                1.723238                1.312722              0.131871
# 4                2.010508                1.417924              0.134689
#
#    onset_delta_var  BERT-GS_Scores
# 0         0.074542       -0.627549
# 1         0.072180       -1.138945
# 2         0.091160       -1.575487
# 3         0.042263       -0.329646
# 4         0.055303       -0.083028
#
# [5 rows x 21 columns]

# %%
out = out.rename(columns={"file_name": "orig_wav_file", "mp3_name":"mp3","speakers": "speaker", 'word_count_y':'word_count',
                  'start_y':'start', 'end_y':'end', 'transcipt':'transcript', 'BERT-GS_Scores':'bert-gs_scores'})

# %%
out.head()
# Out:
#   orig_wav_file                mp3            speaker  word_count   start  \
# 0  142-orig.wav  142-orig_2267.mp3  John_G_Roberts_Jr         105  126.76
# 1  142-orig.wav  142-orig_2268.mp3  John_G_Roberts_Jr          49  227.24
# 2  142-orig.wav  142-orig_2269.mp3    Clarence_Thomas         128  297.56
# 3  142-orig.wav  142-orig_2270.mp3    Clarence_Thomas          83  431.92
# 4  142-orig.wav  142-orig_2271.mp3   Stephen_G_Breyer         191  510.88
#
#       end  duration                                         transcript  \
# 0  169.12     42.36  Mr. Garre, how should we analyze the case if w...
# 1  242.92     15.68  Well, the -- the Special Master concluded that...
# 2  341.56     44.00  Thank you, Mr. Chief Justice. Mr. Garre, a cou...
# 3  465.40     33.48  Well, that's -- you know, that's interesting b...
# 4  588.40     77.52  Well, the part I don't understand, I mean, you...
#
#    log_mean_pitch  log_stdev_pitch  ...  onset_count  onset_rate  \
# 0        5.372137         0.258085  ...          136    3.210576
# 1        5.390368         0.391115  ...           62    3.954082
# 2        6.363312         0.706816  ...          133    3.022727
# 3        5.337352         0.697671  ...          123    3.673835
# 4        5.409414         0.353881  ...          201    2.592879
#
#    onset_time_diff_mean  onset_time_diff_var  onset_strength_mean  \
# 0              0.311704             0.069920             0.981030
# 1              0.247607             0.046463             0.882956
# 2              0.326061             0.080029             0.899064
# 3              0.268328             0.043334             0.769803
# 4              0.374720             0.144677             0.713865
#
#    onset_strength_seg_var  onset_strength_seg_std  onset_delta_abs_mean  \
# 0                2.763874                1.662490              0.167881
# 1                2.563534                1.601104              0.161835
# 2                3.517396                1.875472              0.182482
# 3                1.723238                1.312722              0.131871
# 4                2.010508                1.417924              0.134689
#
#    onset_delta_var  bert-gs_scores
# 0         0.074542       -0.627549
# 1         0.072180       -1.138945
# 2         0.091160       -1.575487
# 3         0.042263       -0.329646
# 4         0.055303       -0.083028
#
# [5 rows x 21 columns]

# %%
out.to_csv('features.csv')

# %%
#import numpy as np
#ln_test = [[1,2,3], [8,9,10]]
#[np.nanmean(np.log(item)) for item in ln_test]

# %%
#[np.log(item) for item in ln_test]
